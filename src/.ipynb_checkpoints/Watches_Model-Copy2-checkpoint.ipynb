# %%
# Build model for watch price utilizing linear regression and lightgbm
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
import lightgbm as lgb
import pickle
from sklearn.pipeline import make_pipeline, Pipeline
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from datetime import date
from tqdm import tqdm
pd.set_option('display.max_columns', None)

# %%
file = 'data/reformatedAndOneHotEncodedDataVer011.csv'

# %%
df = pd.read_csv(file, index_col=[0])
## Re-ordering to ascending order
df = df.iloc[::-1]
df.drop(columns = 'Unnamed: 0', inplace=True)
df['listing__statPrice'] = df['listing__statPrice'].round(2)
# df.drop(df[df['Age'] == '41mm'].index, inplace=True)
# df.drop(df[df['Age'] == '2918'].index, inplace=True)
# df['Age'] = df['Age'].str[:4].astype('int')
# df['Age'] = date.today().year - df['Age']

# %%
df.head()
# Out:
#      listing__statPrice  allDiamond  preciousStone  someDiamonds  \
# 845            39996.07           0              0             0
# 844            20687.62           0              0             0
# 843            19446.37           0              0             0
# 842            24134.25           0              0             0
# 841            16204.42           0              0             0
#
#      braceletRubber  braceletLeather  braceletFabric  braceletMetal  caseGold  \
# 845               0                0               0              1         1
# 844               0                0               0              1         0
# 843               0                0               0              1         0
# 842               0                0               0              1         0
# 841               0                0               0              1         0
#
#      caseEverose  caseRose  caseStainless  caseOyster  caseYellow  \
# 845            0         0              0           0           0
# 844            0         0              1           0           0
# 843            0         0              1           0           0
# 842            0         0              1           0           0
# 841            0         0              1           0           0
#
#      caseDiamond  caseSteel  caseWhite  casePlatinum  CaseSize32  CaseSize34  \
# 845            0          0          1             0           0           0
# 844            0          1          0             0           0           0
# 843            0          1          0             0           0           0
# 842            0          1          0             0           0           0
# 841            0          1          0             0           0           0
#
#      CaseSize36  CaseSize38  CaseSize40  CaseSize42  CaseSize44  \
# 845           0           0           1           0           0
# 844           0           0           1           0           0
# 843           0           0           1           0           0
# 842           0           0           1           0           0
# 841           0           0           0           0           1
#
#      Movementautomatic  Movementquartz  Movementmanual  PapersYes  PapersNo  \
# 845                  1               0               0          1         0
# 844                  1               0               0          1         0
# 843                  1               0               0          1         0
# 842                  1               0               0          0         1
# 841                  1               0               0          1         0
#
#      BoxYes  BoxNo  ConditionAA  ConditionAAA  ConditionA  ConditionB  \
# 845       1      0            0             0           0           0
# 844       1      0            0             0           0           0
# 843       1      0            0             0           0           0
# 842       0      1            0             0           0           0
# 841       1      0            0             0           0           0
#
#      Conditionother  Manufacture2018-2022  Manufacture2013-2017  \
# 845               1                     1                     0
# 844               1                     1                     0
# 843               1                     1                     0
# 842               1                     0                     0
# 841               1                     0                     1
#
#      Manufacture2008-2012  Manufacture2003-2007  ManufactureVintage  \
# 845                     0                     0                   0
# 844                     0                     0                   0
# 843                     0                     0                   0
# 842                     0                     0                   1
# 841                     0                     0                   0
#
#      Productdaydate  Productdatejust  Productoysterperpetual  \
# 845               0                0                       0
# 844               0                0                       0
# 843               0                0                       0
# 842               1                0                       0
# 841               0                0                       0
#
#      Productladydatejust  Productcellini  Productairking  Productgmtmaster  \
# 845                    0               0               0                 1
# 844                    0               0               0                 0
# 843                    0               0               0                 1
# 842                    0               0               0                 0
# 841                    0               0               0                 0
#
#      Productyachtmaster  Productsubmariner  Productcosmographdaytona  \
# 845                   0                  0                         0
# 844                   0                  1                         0
# 843                   0                  0                         0
# 842                   0                  0                         1
# 841                   0                  0                         0
#
#      Productseadweller  Productskydweller  Productexplorer  Productmilgauss  \
# 845                  0                  0                0                0
# 844                  0                  0                0                0
# 843                  0                  0                0                0
# 842                  0                  0                0                0
# 841                  1                  0                0                0
#
#      Productother
# 845             0
# 844             0
# 843             0
# 842             0
# 841             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 846 entries, 845 to 0
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                846 non-null    int64
#  1   listing__statPrice        846 non-null    float64
#  2   allDiamond                846 non-null    int64
#  3   preciousStone             846 non-null    int64
#  4   someDiamonds              846 non-null    int64
#  5   braceletRubber            846 non-null    int64
#  6   braceletLeather           846 non-null    int64
#  7   braceletFabric            846 non-null    int64
#  8   braceletMetal             846 non-null    int64
#  9   caseGold                  846 non-null    int64
#  10  caseEverose               846 non-null    int64
#  11  caseRose                  846 non-null    int64
#  12  caseStainless             846 non-null    int64
#  13  caseOyster                846 non-null    int64
#  14  caseYellow                846 non-null    int64
#  15  caseDiamond               846 non-null    int64
#  16  caseSteel                 846 non-null    int64
#  17  caseWhite                 846 non-null    int64
#  18  casePlatinum              846 non-null    int64
#  19  CaseSize32                846 non-null    int64
#  20  CaseSize34                846 non-null    int64
#  21  CaseSize36                846 non-null    int64
#  22  CaseSize38                846 non-null    int64
#  23  CaseSize40                846 non-null    int64
#  24  CaseSize42                846 non-null    int64
#  25  CaseSize44                846 non-null    int64
#  26  Movementautomatic         846 non-null    int64
#  27  Movementquartz            846 non-null    int64
#  28  Movementmanual            846 non-null    int64
#  29  PapersYes                 846 non-null    int64
#  30  PapersNo                  846 non-null    int64
#  31  BoxYes                    846 non-null    int64
#  32  BoxNo                     846 non-null    int64
#  33  ConditionAA               846 non-null    int64
#  34  ConditionAAA              846 non-null    int64
#  35  ConditionA                846 non-null    int64
#  36  ConditionB                846 non-null    int64
#  37  Conditionother            846 non-null    int64
#  38  Manufacture2018-2022      846 non-null    int64
#  39  Manufacture2013-2017      846 non-null    int64
#  40  Manufacture2008-2012      846 non-null    int64
#  41  Manufacture2003-2007      846 non-null    int64
#  42  ManufactureVintage        846 non-null    int64
#  43  Productdaydate            846 non-null    int64
#  44  Productdatejust           846 non-null    int64
#  45  Productoysterperpetual    846 non-null    int64
#  46  Productladydatejust       846 non-null    int64
#  47  Productcellini            846 non-null    int64
#  48  Productairking            846 non-null    int64
#  49  Productgmtmaster          846 non-null    int64
#  50  Productyachtmaster        846 non-null    int64
#  51  Productsubmariner         846 non-null    int64
#  52  Productcosmographdaytona  846 non-null    int64
#  53  Productseadweller         846 non-null    int64
#  54  Productskydweller         846 non-null    int64
#  55  Productexplorer           846 non-null    int64
#  56  Productmilgauss           846 non-null    int64
#  57  Productother              846 non-null    int64
# dtypes: float64(1), int64(57)
# memory usage: 390.0 KB

# %%
for col in df.columns:
    print(col)
    print(df[col].value_counts(dropna=False))
# Out:
# Unnamed: 0
# 845    1
# 264    1
# 288    1
# 287    1
# 286    1
#       ..
# 560    1
# 559    1
# 558    1
# 557    1
# 0      1
# Name: Unnamed: 0, Length: 846, dtype: int64
# listing__statPrice
# 19449.75    2
# 16281.01    2
# 39996.07    1
# 18509.08    1
# 30305.00    1
#            ..
# 36930.86    1
# 11790.77    1
# 13688.14    1
# 18018.02    1
# 12224.64    1
# Name: listing__statPrice, Length: 844, dtype: int64
# allDiamond
# 0    845
# 1      1
# Name: allDiamond, dtype: int64
# preciousStone
# 0    828
# 1     18
# Name: preciousStone, dtype: int64
# someDiamonds
# 0    802
# 1     44
# Name: someDiamonds, dtype: int64
# braceletRubber
# 0    779
# 1     67
# Name: braceletRubber, dtype: int64
# braceletLeather
# 0    816
# 1     30
# Name: braceletLeather, dtype: int64
# braceletFabric
# 0    845
# 1      1
# Name: braceletFabric, dtype: int64
# braceletMetal
# 1    809
# 0     37
# Name: braceletMetal, dtype: int64
# caseGold
# 0    504
# 1    342
# Name: caseGold, dtype: int64
# caseEverose
# 0    842
# 1      4
# Name: caseEverose, dtype: int64
# caseRose
# 0    770
# 1     76
# Name: caseRose, dtype: int64
# caseStainless
# 1    616
# 0    230
# Name: caseStainless, dtype: int64
# caseOyster
# 0    843
# 1      3
# Name: caseOyster, dtype: int64
# caseYellow
# 0    681
# 1    165
# Name: caseYellow, dtype: int64
# caseDiamond
# 0    841
# 1      5
# Name: caseDiamond, dtype: int64
# caseSteel
# 1    649
# 0    197
# Name: caseSteel, dtype: int64
# caseWhite
# 0    759
# 1     87
# Name: caseWhite, dtype: int64
# casePlatinum
# 0    825
# 1     21
# Name: casePlatinum, dtype: int64
# CaseSize32
# 0    796
# 1     50
# Name: CaseSize32, dtype: int64
# CaseSize34
# 0    834
# 1     12
# Name: CaseSize34, dtype: int64
# CaseSize36
# 0    764
# 1     82
# Name: CaseSize36, dtype: int64
# CaseSize38
# 0    835
# 1     11
# Name: CaseSize38, dtype: int64
# CaseSize40
# 1    448
# 0    398
# Name: CaseSize40, dtype: int64
# CaseSize42
# 0    664
# 1    182
# Name: CaseSize42, dtype: int64
# CaseSize44
# 0    785
# 1     61
# Name: CaseSize44, dtype: int64
# Movementautomatic
# 1    831
# 0     15
# Name: Movementautomatic, dtype: int64
# Movementquartz
# 0    842
# 1      4
# Name: Movementquartz, dtype: int64
# Movementmanual
# 0    835
# 1     11
# Name: Movementmanual, dtype: int64
# PapersYes
# 1    755
# 0     91
# Name: PapersYes, dtype: int64
# PapersNo
# 0    755
# 1     91
# Name: PapersNo, dtype: int64
# BoxYes
# 1    807
# 0     39
# Name: BoxYes, dtype: int64
# BoxNo
# 0    807
# 1     39
# Name: BoxNo, dtype: int64
# ConditionAA
# 0    697
# 1    149
# Name: ConditionAA, dtype: int64
# ConditionAAA
# 0    703
# 1    143
# Name: ConditionAAA, dtype: int64
# ConditionA
# 0    537
# 1    309
# Name: ConditionA, dtype: int64
# ConditionB
# 0    834
# 1     12
# Name: ConditionB, dtype: int64
# Conditionother
# 0    613
# 1    233
# Name: Conditionother, dtype: int64
# Manufacture2018-2022
# 1    515
# 0    331
# Name: Manufacture2018-2022, dtype: int64
# Manufacture2013-2017
# 0    753
# 1     93
# Name: Manufacture2013-2017, dtype: int64
# Manufacture2008-2012
# 0    782
# 1     64
# Name: Manufacture2008-2012, dtype: int64
# Manufacture2003-2007
# 0    786
# 1     60
# Name: Manufacture2003-2007, dtype: int64
# ManufactureVintage
# 0    732
# 1    114
# Name: ManufactureVintage, dtype: int64
# Productdaydate
# 0    668
# 1    178
# Name: Productdaydate, dtype: int64
# Productdatejust
# 0    709
# 1    137
# Name: Productdatejust, dtype: int64
# Productoysterperpetual
# 0    763
# 1     83
# Name: Productoysterperpetual, dtype: int64
# Productladydatejust
# 0    838
# 1      8
# Name: Productladydatejust, dtype: int64
# Productcellini
# 0    839
# 1      7
# Name: Productcellini, dtype: int64
# Productairking
# 0    832
# 1     14
# Name: Productairking, dtype: int64
# Productgmtmaster
# 0    728
# 1    118
# Name: Productgmtmaster, dtype: int64
# Productyachtmaster
# 0    790
# 1     56
# Name: Productyachtmaster, dtype: int64
# Productsubmariner
# 0    711
# 1    135
# Name: Productsubmariner, dtype: int64
# Productcosmographdaytona
# 0    694
# 1    152
# Name: Productcosmographdaytona, dtype: int64
# Productseadweller
# 0    786
# 1     60
# Name: Productseadweller, dtype: int64
# Productskydweller
# 0    810
# 1     36
# Name: Productskydweller, dtype: int64
# Productexplorer
# 0    808
# 1     38
# Name: Productexplorer, dtype: int64
# Productmilgauss
# 0    831
# 1     15
# Name: Productmilgauss, dtype: int64
# Productother
# 0    832
# 1     14
# Name: Productother, dtype: int64

# %%
df.head()

# %% [markdown]
# ### Data Transformations

# %%
y = df['listing__statPrice']
X = df.drop(columns=['product-subtitle', 'Model', 'LOT'], axis=1)
# X = data.drop(['gross'], axis=1)

# Shuffle to false to handle time data
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size = 0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, shuffle=False, test_size = 0.2)

# %%
categorical_cols = ['language', 'country', 'rating']

# %%
# Categorical Preprocessor
categorical_preprocessor = Pipeline(
    steps=[
        # Change to 'ignore' if error raised
        ("OHE", OneHotEncoder(handle_unknown='error', drop='first'))
    ])

# %%
#Combine preprocessors
#Commenting out TfidfVectorizer as it does not help the model
preprocessor = ColumnTransformer(
    transformers=[
        ('text', text_preprocesser, 'plot'),
        ('category', categorical_preprocessor, categorical_cols)
    ])

# %%
# change file path to data
fileName = 'data/reformatedAndOneHotEncodedDataVer011.csv'
df = pd.read_csv(fileName)
# df = df.iloc[::-1]

def split_data(X, y, frac: float = 0.2) -> tuple:
    """Splits data so that it returns a train / test split with a given fraction"""

    # cutoff point for training / test split
    idx_cutoff = int(X.shape[0] * (1 - frac))

    X_train, X_test, y_train, y_test = X.iloc[:idx_cutoff], X.iloc[idx_cutoff:], y.iloc[:idx_cutoff], y.iloc[idx_cutoff:]

    return X_train, X_test, y_train, y_test

# %%
df.reindex(index=df.index[::-1])

# %%
df.head()

# %%
col_list_train = list(df.columns)
col_list_train.remove('listing__statPrice')
# col_list_train.remove('id')


dfX_train = df[col_list_train]
dfy_train = df['listing__statPrice']

X_train, X_test, y_train, y_test = split_data(dfX_train, dfy_train, 0.2)

X_train.head()

# %%
col_list_train = list(df.columns)
col_list_train.remove('listing__statPrice')
# col_list_train.remove('id')


dfX_train = df[col_list_train]
dfy_train = df['listing__statPrice']

X_train, X_test, y_train, y_test = split_data(dfX_train, dfy_train, 0.2)

X_train.head()

# %%
stdScale = StandardScaler()
stdScale.fit_transform(X_train)
stdScale.transform(X_test)

#Set the minimum error arbitrarily large
min = 99999999999999999999999 
count = 0 #Used for keeping track of the iteration number
#How many runs to perform using randomly selected hyperparameters
iterations = 1000
for i in range(iterations):
    print('iteration number', count)
    count += 1 #increment count

    param = {} #initialize parameters
    param['learning_rate'] = np.random.uniform(0, 1)
    # param['num_iterations'] = np.random.randint(100,1000)
    param['boosting_type'] = np.random.choice(['gbdt'])
    # param['objective'] = 'binary'
    param['metric'] = 'mse'
    param['feature_fraction'] = np.random.uniform(0, 1)
    param['num_leaves'] = np.random.randint(5, 300)
    param['min_data_in_leaf'] = np.random.randint(5, 200)
    param['max_depth'] = np.random.randint(5, 300)
    param['early_stopping_round'] = 5
    iterations = np.random.randint(10, 10000)
    print(param, iterations)#Train using selected parameters
    lgbm = LGBMRegressor(**param)
    lgbm.fit(X_train,y_train, eval_set = [(X_test, y_test) , (X_train, y_train)], eval_metric = 'rmse')
    prediction = lgbm.predict(X_test)
    logloss = mean_squared_error(y_true = y_test, y_pred = prediction, squared = False)

    print('logloss:', logloss)
    if logloss < min:
        min = logloss
        pp = param

print("*" * 100)
print('Minimum is: ', min)
print('Used params', pp)

# %%
stdScale = StandardScaler()
stdScale.fit_transform(X_train)
stdScale.transform(X_test)

lgbm_train = LGBMRegressor(learning_rate = 0.12672753417697025, boosting_type = 'gbdt', metric = 'rmse', feature_fraction = 0.25975871059387023, num_leaves = 261, min_data_in_leaf = 11, max_depth = 137, early_stopping_round = 5)
lgbm_train.fit(X_train,y_train, eval_set = [(X_test, y_test) , (X_train, y_train)], eval_metric = 'rmse')
prediction = lgbm_train.predict(X_test)
print(mean_squared_error(y_true = y_test, y_pred = prediction, squared = False))
# lgb.plot_importance(lgbm)
# print('Training accuracy {:.4f}'.format(lgbm.score(X_train,y_train)))
# print('Testing accuracy {:.4f}'.format(lgbm.score(X_test,y_test)))
prediction

# %%
# Model for linear regression
mod_pipeline = Pipeline([('scaler', StandardScaler()), ('linearRegression', LinearRegression())])
mod_pipeline.fit(X_train, y_train)
test_score = mod_pipeline.score(X_test, y_test)
test_score
## 0.543308485096857 with model training recent sales


## -5.813872016504329e+21 data reversed using onehotencode data
## 0.5415915991663093

# %%
lr_pipe = make_pipeline(
    preprocessor, 
    StandardScaler(with_mean=False), 
    LinearRegression()
)

lasso_pipe = make_pipeline(
    preprocessor, 
    StandardScaler(with_mean=False), 
    Lasso()
)

ridge_pipe = make_pipeline(
    preprocessor, 
    StandardScaler(with_mean=False), 
    Ridge()
)

rf_pipe = make_pipeline(
    preprocessor, 
    StandardScaler(with_mean=False), 
    RandomForestRegressor(random_state = 42)
)

# %%
lr_pipe.fit(X_train, y_train)
train_score = lr_pipe.score(X_train, y_train)
val_score = lr_pipe.score(X_val, y_val)
test_score = lr_pipe.score(X_test, y_test)
val_pred = lr_pipe.predict(X_val)
test_pred = lr_pipe.predict(X_test)

print('Linear Regression Results')
print("Train score:", train_score)
print("Val score:", val_score)
print("Test score:", test_score)
print("Val RMSE:", np.sqrt(mean_squared_error(y_val, val_pred)))
print("Test RMSE:", np.sqrt(mean_squared_error(y_test, test_pred)))

# %%
filename = 'watches_lgbm_model.pkl'
pickle.dump(lgbm, open(filename, 'wb'))
